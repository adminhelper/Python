# %% [markdown]
# # 주피터 노트북 테스트
#  주피터 노트북은 웹서버에 브라우저가 접속해서 프로그래밍 할 수 있는 개발 환경입니다
#
#  ## numpy의 sin 테스트

# %%
num = 100
print(num)
# Out:
# 100

# %%
print(num)
print(type(num))
# Out:
# 100
# <class 'int'>

# %%
num = "홍길동"
print(num)
print(type(num))
# Out:
# 홍길동
# <class 'str'>

# %%
2**32
# Out:
# 4294967296

# %%
(2**64)/2
# Out:
# 9.223372036854776e+18

# %%
2**500
# Out:
# 3273390607896141870013189696827599152216642046043064789483291368096133796404674554883270092325904157150886684127560071009217256545885393053328527589376

# %%
10**500
# Out:
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import numpy as np 
x = np.arange(-20, 20, 0.1) 
y = np.sin(x) 
plt.plot(x, y)
